# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sn
import matplotlib.pyplot as plt
sn.set(style='ticks')


countAB=0
countNO=0
column_names=['pelvic incidence','pelvic tilt','lumbar lordosis angle','sacral slope',
                  'pelvic radius','grade of spondylolisthesis','Class']
Data=pd.read_csv('HW1_Dataset/vertebral_column_data/column_2C.dat',sep='\s+',names=column_names,header=None)
Data
# Out:
#      pelvic incidence  pelvic tilt  lumbar lordosis angle  sacral slope  \
# 0               63.03        22.55                  39.61         40.48
# 1               39.06        10.06                  25.02         29.00
# 2               68.83        22.22                  50.09         46.61
# 3               69.30        24.65                  44.31         44.64
# 4               49.71         9.65                  28.32         40.06
# 5               40.25        13.92                  25.12         26.33
# 6               53.43        15.86                  37.17         37.57
# 7               45.37        10.76                  29.04         34.61
# 8               43.79        13.53                  42.69         30.26
# 9               36.69         5.01                  41.95         31.68
# 10              49.71        13.04                  31.33         36.67
# 11              31.23        17.72                  15.50         13.52
# ...
